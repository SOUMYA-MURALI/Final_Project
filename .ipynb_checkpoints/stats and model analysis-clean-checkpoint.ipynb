# %%
#Importing all the libraries 
import csv
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
listings_1=pd.read_csv("/Users/jennbrockman/Desktop/Ireland/data/listings1.csv",encoding = 'utf-8')
# Out:
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Listing the original dataset
listings_1=listings_1.set_index('id')

# %%
#Listing the data types of each column
listings_1.dtypes
# Out:
# listing_url                                      object
# scrape_id                                       float64
# last_scraped                                     object
# name                                             object
# summary                                          object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 105, dtype: object

# %%
listings_1
# Out:
#                                     listing_url     scrape_id last_scraped  \
# id
# 44077        https://www.airbnb.com/rooms/44077  2.019110e+13     11/26/19
# 85148        https://www.airbnb.com/rooms/85148  2.019110e+13     11/26/19
# 85156        https://www.airbnb.com/rooms/85156  2.019110e+13     11/26/19
# 121030      https://www.airbnb.com/rooms/121030  2.019110e+13     11/26/19
# 159889      https://www.airbnb.com/rooms/159889  2.019110e+13     11/26/19
# ...                                         ...           ...          ...
# 40369511  https://www.airbnb.com/rooms/40369511  2.019110e+13     11/26/19
# 40373285  https://www.airbnb.com/rooms/40373285  2.019110e+13     11/26/19
# 40373911  https://www.airbnb.com/rooms/40373911  2.019110e+13     11/26/19
# 40376312  https://www.airbnb.com/rooms/40376312  2.019110e+13     11/26/19
# 40377227  https://www.airbnb.com/rooms/40377227  2.019110e+13     11/26/19
#
#                                                        name  \
# id
# 44077                   cosy comfortable Irish cottage twin
# 85148                      Habitación en Dublín Double room
# 85156          Cosy Comfortable Irish Cottage  1 Double Bed
# 121030                  Comfy double room in central area 1
# 159889                                 Friendly Single Room
# ...                                                     ...
# 40369511             Lovely house in the heart of Glasthule
# 40373285                      Cosy House beside Dublin City
# 40373911  Cozy Family Home 10 min drive to Blanchardstow...
# 40376312                      Single Bed 2 in a Double room
# 40377227      Double room with own bathroom - 2 single beds
#
#                                                     summary  \
# id
# 44077     Our house was built in 1937 when there was ple...
# 85148                                                   NaN
# 85156     Our Cottage is a charming light filled cottage...
# 121030    Welcoming victorian house. Breakfast included....
# 159889    washing can be done at a cost of five euro per...
# ...                                                     ...
# 40369511  An inviting and cosy two bed terraced house in...
# 40373285  Welcome to our home! Ideal room for a solo tra...
# 40373911  Cozy 3 bed semi-d beside clonee village with l...
# 40376312  Cozy apartment in a quiet and nice neighborhoo...
# 40377227  Cozy apartment in a quiet and nice neighborhoo...
#
#                                                       space  \
# id
# 44077     Hi, My name is Teresa and we  have 3 rooms ava...
# 85148     I'm renting a double room in my house in the s...
# 85156     Hi , My name is Teresa and we  have 3 rooms av...
# 121030    Double room 1 upstairs,wooden floors, desk, in...
# 159889    Nice comfortable house 20 minutes from the Cit...
# ...                                                     ...
# 40369511  Beautiful seaside walks and incredible food & ...
# 40373285  Both Bedrooms have a double bed and wardrobe s...
# 40373911                                                NaN
# 40376312  New apartment, fully equipped with all furnitu...
# 40377227  New apartment, fully equipped with all furnitu...
#
#                                                 description  \
# id
# 44077     Our house was built in 1937 when there was ple...
# 85148     I'm renting a double room in my house in the s...
# 85156     Our Cottage is a charming light filled cottage...
# 121030    Welcoming victorian house. Breakfast included....
# 159889    washing can be done at a cost of five euro per...
# ...                                                     ...
# 40369511  An inviting and cosy two bed terraced house in...
# 40373285  Welcome to our home! Ideal room for a solo tra...
# 40373911  Cozy 3 bed semi-d beside clonee village with l...
# 40376312  Cozy apartment in a quiet and nice neighborhoo...
# 40377227  Cozy apartment in a quiet and nice neighborhoo...
#
#          experiences_offered  \
# id
# 44077                   none
# 85148                   none
# 85156                   none
# 121030                social
# 159889                  none
# ...                      ...
# 40369511                none
# 40373285                none
# 40373911                none
# 40376312                none
# 40377227                none
#
#                                       neighborhood_overview  \
# id
# 44077     I like our neighbourhood as there is no shorta...
# 85148                                                   NaN
# 85156     I love Dundrum and its surrounding areas , The...
# 121030    My neighbourhood is very safe, friendly  and o...
# 159889    plenty of buses into the city and the area is ...
# ...                                                     ...
# 40369511  Nestled between the busy towns of Dun Laoghair...
# 40373285  Drumcondra, County Dublin, Ireland Croke Park,...
# 40373911  Quite leafy suburban location 25mins from city...
# 40376312  Well located in central Tallaght, with everyth...
# 40377227  Well located in central Tallaght, with everyth...
#
#                                                       notes  ...  \
# id                                                           ...
# 44077     Dundrum was always known as a Spa Town and the...  ...
# 85148                                                   NaN  ...
# 85156     We are always prepared to go the extra mile so...  ...
# 121030    I can help you with questions about history an...  ...
# 159889    we also do a departure run to the airport at a...  ...
# ...                                                     ...  ...
# 40369511                                                NaN  ...
# 40373285                                                NaN  ...
# 40373911                                                NaN  ...
# 40376312                                                NaN  ...
# 40377227                                                NaN  ...
#
#          instant_bookable is_business_travel_ready  \
# id
# 44077                   t                        f
# 85148                   f                        f
# 85156                   t                        f
# 121030                  f                        f
# 159889                  t                        f
# ...                   ...                      ...
# 40369511                t                        f
# 40373285                f                        f
# 40373911                t                        f
# 40376312                f                        f
# 40377227                f                        f
#
#                   cancellation_policy require_guest_profile_picture  \
# id
# 44077                        moderate                             t
# 85148                        flexible                             f
# 85156                        moderate                             t
# 121030    strict_14_with_grace_period                             f
# 159889    strict_14_with_grace_period                             f
# ...                               ...                           ...
# 40369511                     flexible                             f
# 40373285                     moderate                             f
# 40373911                     flexible                             f
# 40376312                     moderate                             f
# 40377227                     moderate                             f
#
#           require_guest_phone_verification  calculated_host_listings_count  \
# id
# 44077                                    t                               3
# 85148                                    f                               1
# 85156                                    t                               3
# 121030                                   f                               3
# 159889                                   t                               3
# ...                                    ...                             ...
# 40369511                                 f                               1
# 40373285                                 f                               1
# 40373911                                 f                               1
# 40376312                                 f                               3
# 40377227                                 f                               3
#
#          calculated_host_listings_count_entire_homes  \
# id
# 44077                                              0
# 85148                                              0
# 85156                                              0
# 121030                                             0
# 159889                                             0
# ...                                              ...
# 40369511                                           1
# 40373285                                           1
# 40373911                                           1
# 40376312                                           0
# 40377227                                           0
#
#           calculated_host_listings_count_private_rooms  \
# id
# 44077                                                3
# 85148                                                1
# 85156                                                3
# 121030                                               3
# 159889                                               3
# ...                                                ...
# 40369511                                             0
# 40373285                                             0
# 40373911                                             0
# 40376312                                             1
# 40377227                                             1
#
#           calculated_host_listings_count_shared_rooms reviews_per_month
# id
# 44077                                               0              2.07
# 85148                                               0              0.15
# 85156                                               0              1.64
# 121030                                              0              1.07
# 159889                                              0              3.25
# ...                                               ...               ...
# 40369511                                            0               NaN
# 40373285                                            0               NaN
# 40373911                                            0               NaN
# 40376312                                            2               NaN
# 40377227                                            2               NaN
#
# [9437 rows x 105 columns]

# %%
# Checking the statistics of the columns
listings_1.describe().transpose()
# Out:
#                                                count          mean  \
# scrape_id                                     9437.0  2.019110e+13
# thumbnail_url                                    0.0           NaN
# medium_url                                       0.0           NaN
# xl_picture_url                                   0.0           NaN
# host_id                                       9437.0  8.923157e+07
# host_acceptance_rate                             0.0           NaN
# host_listings_count                           9427.0  6.104593e+00
# host_total_listings_count                     9427.0  6.104593e+00
# neighbourhood_group_cleansed                     0.0           NaN
# latitude                                      9437.0  5.334570e+01
# longitude                                     9437.0 -6.254889e+00
# accommodates                                  9437.0  3.151319e+00
# bathrooms                                     9433.0  1.312255e+00
# bedrooms                                      9432.0  1.468193e+00
# beds                                          9412.0  1.859860e+00
# square_feet                                     27.0  4.435926e+02
# guests_included                               9437.0  1.521352e+00
# minimum_nights                                9437.0  4.226979e+00
# maximum_nights                                9437.0  6.194213e+02
# minimum_minimum_nights                        9437.0  3.938222e+00
# maximum_minimum_nights                        9437.0  5.012080e+00
# minimum_maximum_nights                        9437.0  6.183501e+02
# maximum_maximum_nights                        9437.0  6.282420e+02
# minimum_nights_avg_ntm                        9437.0  4.401717e+00
# maximum_nights_avg_ntm                        9437.0  6.209858e+02
# availability_30                               9437.0  7.327858e+00
# availability_60                               9437.0  1.634407e+01
# availability_90                               9437.0  2.642386e+01
# availability_365                              9437.0  7.641104e+01
# number_of_reviews                             9437.0  3.807047e+01
# number_of_reviews_ltm                         9437.0  1.434693e+01
# review_scores_rating                          7846.0  9.322190e+01
# review_scores_accuracy                        7836.0  9.625447e+00
# review_scores_cleanliness                     7838.0  9.350089e+00
# review_scores_checkin                         7832.0  9.723825e+00
# review_scores_communication                   7839.0  9.747289e+00
# review_scores_location                        7835.0  9.508998e+00
# review_scores_value                           7832.0  9.246170e+00
# jurisdiction_names                               0.0           NaN
# calculated_host_listings_count                9437.0  3.903677e+00
# calculated_host_listings_count_entire_homes   9437.0  2.602628e+00
# calculated_host_listings_count_private_rooms  9437.0  1.131610e+00
# calculated_host_listings_count_shared_rooms   9437.0  5.881106e-02
# reviews_per_month                             7997.0  1.953966e+00
#
#                                                        std           min  \
# scrape_id                                     0.000000e+00  2.019110e+13
# thumbnail_url                                          NaN           NaN
# medium_url                                             NaN           NaN
# xl_picture_url                                         NaN           NaN
# host_id                                       8.296647e+07  4.398400e+04
# host_acceptance_rate                                   NaN           NaN
# host_listings_count                           3.879246e+01  0.000000e+00
# host_total_listings_count                     3.879246e+01  0.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      4.353452e-02  5.320836e+01
# longitude                                     5.817851e-02 -6.519370e+00
# accommodates                                  2.054625e+00  1.000000e+00
# bathrooms                                     6.145331e-01  0.000000e+00
# bedrooms                                      9.280361e-01  0.000000e+00
# beds                                          1.424177e+00  0.000000e+00
# square_feet                                   6.345569e+02  0.000000e+00
# guests_included                               1.197485e+00  1.000000e+00
# minimum_nights                                2.009870e+01  1.000000e+00
# maximum_nights                                5.433313e+02  1.000000e+00
# minimum_minimum_nights                        1.996815e+01  1.000000e+00
# maximum_minimum_nights                        2.238408e+01  1.000000e+00
# minimum_maximum_nights                        5.417993e+02  1.000000e+00
# maximum_maximum_nights                        5.401186e+02  1.000000e+00
# minimum_nights_avg_ntm                        2.102065e+01  1.000000e+00
# maximum_nights_avg_ntm                        5.410307e+02  1.000000e+00
# availability_30                               9.902394e+00  0.000000e+00
# availability_60                               2.025549e+01  0.000000e+00
# availability_90                               3.194513e+01  0.000000e+00
# availability_365                              1.097912e+02  0.000000e+00
# number_of_reviews                             6.535361e+01  0.000000e+00
# number_of_reviews_ltm                         2.293544e+01  0.000000e+00
# review_scores_rating                          8.202618e+00  2.000000e+01
# review_scores_accuracy                        7.590077e-01  2.000000e+00
# review_scores_cleanliness                     1.008156e+00  2.000000e+00
# review_scores_checkin                         6.675462e-01  2.000000e+00
# review_scores_communication                   6.383967e-01  2.000000e+00
# review_scores_location                        7.355202e-01  2.000000e+00
# review_scores_value                           8.614523e-01  2.000000e+00
# jurisdiction_names                                     NaN           NaN
# calculated_host_listings_count                9.105776e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   8.778103e+00  0.000000e+00
# calculated_host_listings_count_private_rooms  2.267846e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   6.804015e-01  0.000000e+00
# reviews_per_month                             2.251925e+00  2.000000e-02
#
#                                                        25%           50%  \
# scrape_id                                     2.019110e+13  2.019110e+13
# thumbnail_url                                          NaN           NaN
# medium_url                                             NaN           NaN
# xl_picture_url                                         NaN           NaN
# host_id                                       2.279928e+07  5.676244e+07
# host_acceptance_rate                                   NaN           NaN
# host_listings_count                           1.000000e+00  1.000000e+00
# host_total_listings_count                     1.000000e+00  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.333036e+01  5.334398e+01
# longitude                                    -6.277840e+00 -6.259160e+00
# accommodates                                  2.000000e+00  2.000000e+00
# bathrooms                                     1.000000e+00  1.000000e+00
# bedrooms                                      1.000000e+00  1.000000e+00
# beds                                          1.000000e+00  1.000000e+00
# square_feet                                   0.000000e+00  2.000000e+01
# guests_included                               1.000000e+00  1.000000e+00
# minimum_nights                                1.000000e+00  2.000000e+00
# maximum_nights                                1.500000e+01  1.125000e+03
# minimum_minimum_nights                        1.000000e+00  2.000000e+00
# maximum_minimum_nights                        1.000000e+00  2.000000e+00
# minimum_maximum_nights                        1.500000e+01  1.125000e+03
# maximum_maximum_nights                        2.000000e+01  1.125000e+03
# minimum_nights_avg_ntm                        1.000000e+00  2.000000e+00
# maximum_nights_avg_ntm                        2.000000e+01  1.125000e+03
# availability_30                               0.000000e+00  0.000000e+00
# availability_60                               0.000000e+00  2.000000e+00
# availability_90                               0.000000e+00  5.000000e+00
# availability_365                              0.000000e+00  1.700000e+01
# number_of_reviews                             2.000000e+00  1.000000e+01
# number_of_reviews_ltm                         0.000000e+00  3.000000e+00
# review_scores_rating                          9.000000e+01  9.500000e+01
# review_scores_accuracy                        9.000000e+00  1.000000e+01
# review_scores_cleanliness                     9.000000e+00  1.000000e+01
# review_scores_checkin                         1.000000e+01  1.000000e+01
# review_scores_communication                   1.000000e+01  1.000000e+01
# review_scores_location                        9.000000e+00  1.000000e+01
# review_scores_value                           9.000000e+00  9.000000e+00
# jurisdiction_names                                     NaN           NaN
# calculated_host_listings_count                1.000000e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   0.000000e+00  1.000000e+00
# calculated_host_listings_count_private_rooms  0.000000e+00  1.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             3.200000e-01  1.120000e+00
#
#                                                        75%           max
# scrape_id                                     2.019110e+13  2.019110e+13
# thumbnail_url                                          NaN           NaN
# medium_url                                             NaN           NaN
# xl_picture_url                                         NaN           NaN
# host_id                                       1.401056e+08  3.120656e+08
# host_acceptance_rate                                   NaN           NaN
# host_listings_count                           3.000000e+00  7.760000e+02
# host_total_listings_count                     3.000000e+00  7.760000e+02
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.335745e+01  5.361436e+01
# longitude                                    -6.235380e+00 -6.025940e+00
# accommodates                                  4.000000e+00  1.600000e+01
# bathrooms                                     1.500000e+00  8.500000e+00
# bedrooms                                      2.000000e+00  1.300000e+01
# beds                                          2.000000e+00  1.800000e+01
# square_feet                                   6.785000e+02  2.500000e+03
# guests_included                               2.000000e+00  1.500000e+01
# minimum_nights                                3.000000e+00  1.125000e+03
# maximum_nights                                1.125000e+03  1.203000e+03
# minimum_minimum_nights                        3.000000e+00  1.125000e+03
# maximum_minimum_nights                        3.000000e+00  1.125000e+03
# minimum_maximum_nights                        1.125000e+03  1.203000e+03
# maximum_maximum_nights                        1.125000e+03  1.203000e+03
# minimum_nights_avg_ntm                        3.000000e+00  1.125000e+03
# maximum_nights_avg_ntm                        1.125000e+03  1.203000e+03
# availability_30                               1.500000e+01  3.000000e+01
# availability_60                               3.300000e+01  6.000000e+01
# availability_90                               5.600000e+01  9.000000e+01
# availability_365                              1.130000e+02  3.650000e+02
# number_of_reviews                             4.400000e+01  6.700000e+02
# number_of_reviews_ltm                         2.000000e+01  2.420000e+02
# review_scores_rating                          9.900000e+01  1.000000e+02
# review_scores_accuracy                        1.000000e+01  1.000000e+01
# review_scores_cleanliness                     1.000000e+01  1.000000e+01
# review_scores_checkin                         1.000000e+01  1.000000e+01
# review_scores_communication                   1.000000e+01  1.000000e+01
# review_scores_location                        1.000000e+01  1.000000e+01
# review_scores_value                           1.000000e+01  1.000000e+01
# jurisdiction_names                                     NaN           NaN
# calculated_host_listings_count                3.000000e+00  7.800000e+01
# calculated_host_listings_count_entire_homes   1.000000e+00  7.800000e+01
# calculated_host_listings_count_private_rooms  1.000000e+00  2.500000e+01
# calculated_host_listings_count_shared_rooms   0.000000e+00  1.400000e+01
# reviews_per_month                             2.910000e+00  3.846000e+01

# %%
#Creating another dataframe
listings=listings_1

# %%
#Converting price to a float
listings['price'] = listings['price'].str.replace('$', '')
listings['price'] = listings['price'].str.replace(',', '').astype('float64')

# %%
#Correlation Matrix to see the most correlated features with price
fig, ax = plt.subplots(figsize=(16,14))
corr = listings.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, linewidths=.5, ax=ax)
corr['price'].sort_values(ascending=False)
# Out:
# price                                           1.000000
# square_feet                                     0.496691
# accommodates                                    0.246697
# bedrooms                                        0.231114
# bathrooms                                       0.213303
# beds                                            0.199820
# guests_included                                 0.102845
# host_id                                         0.059343
# maximum_nights                                  0.052470
# availability_365                                0.042627
# calculated_host_listings_count_entire_homes     0.041113
# calculated_host_listings_count                  0.028212
# review_scores_location                          0.026195
# maximum_minimum_nights                          0.025315
# reviews_per_month                               0.024415
# minimum_nights_avg_ntm                          0.021886
# maximum_maximum_nights                          0.021356
# availability_60                                 0.020509
# availability_90                                 0.019262
# maximum_nights_avg_ntm                          0.018228
# host_listings_count                             0.017763
# host_total_listings_count                       0.017763
# minimum_nights                                  0.016799
# availability_30                                 0.016727
# minimum_minimum_nights                          0.014658
# minimum_maximum_nights                          0.014380
# longitude                                       0.012128
# review_scores_cleanliness                       0.006421
# number_of_reviews_ltm                          -0.010618
# review_scores_rating                           -0.015529
# review_scores_accuracy                         -0.019835
# calculated_host_listings_count_shared_rooms    -0.023838
# review_scores_communication                    -0.026142
# review_scores_value                            -0.026846
# latitude                                       -0.030131
# number_of_reviews                              -0.031924
# calculated_host_listings_count_private_rooms   -0.042409
# review_scores_checkin                          -0.042687
# scrape_id                                            NaN
# thumbnail_url                                        NaN
# medium_url                                           NaN
# xl_picture_url                                       NaN
# host_acceptance_rate                                 NaN
# neighbourhood_group_cleansed                         NaN
# jurisdiction_names                                   NaN
# Name: price, dtype: float64

# %%
#Based on the above correlations and a sense test, we select the follwing features for our models
listings.head()
selected_columns = [
                'id',
                'host_response_rate',
                'host_is_superhost',
                'zipcode',
                'property_type',
                'room_type',
                'accommodates',
                'bathrooms',
                'bedrooms',
                'beds',
                'bed_type',
                'amenities',
                'price',
                'guests_included',
                'review_scores_rating',
                'review_scores_accuracy',
                'review_scores_cleanliness',
                'review_scores_checkin',
                'review_scores_communication',
                'review_scores_location',
                'review_scores_value'
]

listings.drop( 
    [key for key in listings.keys() if key not in selected_columns] ,
    axis=1, 
    inplace=True)

#Since amenities is a textual feature, and we know longer the amenities means more the amenities which should be directly correlated to the price. So calculating the length of the amenities
listings.loc[:,'amenities_length'] = listings['amenities'].str.len()

#Dropping the original amenities column
listings = listings.drop(['amenities'], 1)

# %%
import seaborn as sns
import nltk
nltk.download('vader_lexicon')
from ipykernel import kernelapp as app
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jennbrockman/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
reviews = pd.read_csv("/Users/jennbrockman/Desktop/Ireland/data/reviews1.csv")
reviews  = reviews.dropna()
reviews.head()
reviews=reviews.set_index('listing_id')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

reviews['polarity_value']="Default"
reviews['neg']=0.0
reviews['pos']=0.0
reviews['neu']=0.0
reviews['compound']=0.0
for index,row in reviews.iterrows():
    ss = sid.polarity_scores(row['comments'])
    reviews.set_value(index,'polarity_value',ss)
    reviews.set_value(index,'neg',ss['neg'])
    reviews.set_value(index,'pos',ss['pos'])
    reviews.set_value(index,'neu',ss['neu'])
    reviews.set_value(index,'compound',ss['compound'])
# Out:
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/jennbrockman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app

# %%
reviews.head()

# %%
rscore=reviews.groupby('listing_id')['compound'].mean()

# %%
rscore

# %%
#Joining the two dataframes by ID 
listings_final = pd.concat([listings, rscore], axis=1, join='inner')

# %%
listings_final
# Out:
#          host_response_rate host_is_superhost    zipcode property_type  \
# 44077                  100%                 t  Dublin 14      Bungalow
# 85148                  100%                 f        NaN         House
# 85156                  100%                 t  Dublin 14      Bungalow
# 121030                  83%                 f   Dublin 4         House
# 159889                 100%                 f   Dublin 9         House
# ...                     ...               ...        ...           ...
# 40105183               100%                 f        NaN     Apartment
# 40115872               100%                 f        NaN         House
# 40225192               100%                 f   D05 FH39         House
# 40232557               100%                 f   D09 YK11         House
# 40248083               100%                 f        NaN         House
#
#              room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 44077     Private room             2        1.5       1.0   2.0  Real Bed
# 85148     Private room             2        NaN       1.0   1.0  Real Bed
# 85156     Private room             2        1.5       1.0   1.0  Real Bed
# 121030    Private room             2        2.0       1.0   1.0  Real Bed
# 159889    Private room             1        2.0       3.0   6.0  Real Bed
# ...                ...           ...        ...       ...   ...       ...
# 40105183  Private room             2        1.0       1.0   1.0  Real Bed
# 40115872  Private room             2        1.0       0.0   1.0  Real Bed
# 40225192  Private room             2        2.5       1.0   1.0  Real Bed
# 40232557  Private room             2        1.5       1.0   1.0  Real Bed
# 40248083  Private room             5        1.5       1.0   4.0  Real Bed
#
#           ...  guests_included  review_scores_rating  review_scores_accuracy  \
# 44077     ...                1                  95.0                    10.0
# 85148     ...                1                   NaN                     NaN
# 85156     ...                1                  96.0                    10.0
# 121030    ...                1                  94.0                     9.0
# 159889    ...                1                  95.0                    10.0
# ...       ...              ...                   ...                     ...
# 40105183  ...                1                 100.0                    10.0
# 40115872  ...                1                 100.0                    10.0
# 40225192  ...                1                 100.0                    10.0
# 40232557  ...                1                   NaN                     NaN
# 40248083  ...                1                 100.0                    10.0
#
#           review_scores_cleanliness  review_scores_checkin  \
# 44077                          10.0                   10.0
# 85148                           NaN                    NaN
# 85156                          10.0                   10.0
# 121030                          9.0                   10.0
# 159889                         10.0                   10.0
# ...                             ...                    ...
# 40105183                       10.0                   10.0
# 40115872                       10.0                   10.0
# 40225192                       10.0                   10.0
# 40232557                        NaN                    NaN
# 40248083                       10.0                   10.0
#
#           review_scores_communication  review_scores_location  \
# 44077                            10.0                    10.0
# 85148                             NaN                     NaN
# 85156                            10.0                     9.0
# 121030                            9.0                     9.0
# 159889                           10.0                    10.0
# ...                               ...                     ...
# 40105183                         10.0                    10.0
# 40115872                         10.0                     8.0
# 40225192                         10.0                    10.0
# 40232557                          NaN                     NaN
# 40248083                         10.0                    10.0
#
#           review_scores_value  amenities_length  compound
# 44077                    10.0               633    0.8555
# 85148                     NaN               172    0.0000
# 85156                    10.0               637    0.4215
# 121030                    9.0               210    0.8547
# 159889                   10.0               488    0.8687
# ...                       ...               ...       ...
# 40105183                 10.0               217    0.9654
# 40115872                 10.0               121    0.8350
# 40225192                 10.0               281    0.9746
# 40232557                  NaN               255    0.0000
# 40248083                 10.0               161    0.9914
#
# [7997 rows x 21 columns]

# %%
#Converting the true/false values to binary 0/1
listings_final['host_is_superhost'].replace('t',1, inplace=True)
listings_final['host_is_superhost'].replace('f',0, inplace=True)

#Converting acceptance/response percentages to numbers
listings_final['host_response_rate'] = listings_final['host_response_rate'].replace('%','',regex=True).astype('float64')/100.00

# %%
#Recoding property_type values 
def recode(value):
    if value not in ['House', 'Apartment', 'Touwnhouse', 'Condominium']:
        return 'Other'
    return value

listings_final['property_type'] = listings_final['property_type'].apply(recode)

# %%
#Recoding bed_type values
def recode(value):
    if value not in ['Real Bed']:
        return 'Other'
    return value

listings_final['bed_type'] = listings_final['bed_type'].apply(recode)

# %%
#Filling the empty values in the columns
listings_final['bathrooms'].fillna(method='ffill', inplace=True)
listings_final['bedrooms'].fillna(method='ffill', inplace=True)
listings_final['beds'].fillna(method='ffill', inplace=True)
listings_final['host_is_superhost'].fillna(value=0,inplace=True)
listings_final['host_response_rate'].fillna(value=0,inplace=True)

# %%
listings_final
# Out:
#           host_response_rate  host_is_superhost    zipcode property_type  \
# 44077                   1.00                1.0  Dublin 14         Other
# 85148                   1.00                0.0        NaN         House
# 85156                   1.00                1.0  Dublin 14         Other
# 121030                  0.83                0.0   Dublin 4         House
# 159889                  1.00                0.0   Dublin 9         House
# ...                      ...                ...        ...           ...
# 40105183                1.00                0.0        NaN     Apartment
# 40115872                1.00                0.0        NaN         House
# 40225192                1.00                0.0   D05 FH39         House
# 40232557                1.00                0.0   D09 YK11         House
# 40248083                1.00                0.0        NaN         House
#
#              room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 44077     Private room             2        1.5       1.0   2.0  Real Bed
# 85148     Private room             2        1.5       1.0   1.0  Real Bed
# 85156     Private room             2        1.5       1.0   1.0  Real Bed
# 121030    Private room             2        2.0       1.0   1.0  Real Bed
# 159889    Private room             1        2.0       3.0   6.0  Real Bed
# ...                ...           ...        ...       ...   ...       ...
# 40105183  Private room             2        1.0       1.0   1.0  Real Bed
# 40115872  Private room             2        1.0       0.0   1.0  Real Bed
# 40225192  Private room             2        2.5       1.0   1.0  Real Bed
# 40232557  Private room             2        1.5       1.0   1.0  Real Bed
# 40248083  Private room             5        1.5       1.0   4.0  Real Bed
#
#           ...  guests_included  review_scores_rating  review_scores_accuracy  \
# 44077     ...                1                  95.0                    10.0
# 85148     ...                1                   NaN                     NaN
# 85156     ...                1                  96.0                    10.0
# 121030    ...                1                  94.0                     9.0
# 159889    ...                1                  95.0                    10.0
# ...       ...              ...                   ...                     ...
# 40105183  ...                1                 100.0                    10.0
# 40115872  ...                1                 100.0                    10.0
# 40225192  ...                1                 100.0                    10.0
# 40232557  ...                1                   NaN                     NaN
# 40248083  ...                1                 100.0                    10.0
#
#           review_scores_cleanliness  review_scores_checkin  \
# 44077                          10.0                   10.0
# 85148                           NaN                    NaN
# 85156                          10.0                   10.0
# 121030                          9.0                   10.0
# 159889                         10.0                   10.0
# ...                             ...                    ...
# 40105183                       10.0                   10.0
# 40115872                       10.0                   10.0
# 40225192                       10.0                   10.0
# 40232557                        NaN                    NaN
# 40248083                       10.0                   10.0
#
#           review_scores_communication  review_scores_location  \
# 44077                            10.0                    10.0
# 85148                             NaN                     NaN
# 85156                            10.0                     9.0
# 121030                            9.0                     9.0
# 159889                           10.0                    10.0
# ...                               ...                     ...
# 40105183                         10.0                    10.0
# 40115872                         10.0                     8.0
# 40225192                         10.0                    10.0
# 40232557                          NaN                     NaN
# 40248083                         10.0                    10.0
#
#           review_scores_value  amenities_length  compound
# 44077                    10.0               633    0.8555
# 85148                     NaN               172    0.0000
# 85156                    10.0               637    0.4215
# 121030                    9.0               210    0.8547
# 159889                   10.0               488    0.8687
# ...                       ...               ...       ...
# 40105183                 10.0               217    0.9654
# 40115872                 10.0               121    0.8350
# 40225192                 10.0               281    0.9746
# 40232557                  NaN               255    0.0000
# 40248083                 10.0               161    0.9914
#
# [7997 rows x 21 columns]

# %%
listings_final.isna().sum()
# Out:
# host_response_rate                0
# host_is_superhost                 0
# zipcode                        3865
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# bed_type                          0
# price                             0
# guests_included                   0
# review_scores_rating            151
# review_scores_accuracy          161
# review_scores_cleanliness       159
# review_scores_checkin           165
# review_scores_communication     158
# review_scores_location          162
# review_scores_value             165
# amenities_length                  0
# compound                          0
# dtype: int64

# %%
#Creating distribution charts for all the numbered features
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numdf = listings_final.select_dtypes(include=numerics)
numdf = numdf.dropna(axis=0, how='any')
numdf_variables = list(numdf)

graphs = len(numdf_variables)-1

position = []
for i in range(6):
    for j in range(3):
        b = i,j
        position.append(b)
        
fig, axes = plt.subplots(nrows=6, ncols=3, sharey=False, sharex=False, figsize=(12,20))
fig.subplots_adjust(hspace=.5)

for i in range(graphs):
    sns.distplot(numdf[numdf_variables[i]], ax=axes[position[i]], kde=False)

# %%
#Correlation Matrix with the remaining features
fig, ax = plt.subplots(figsize=(16,12))
corr = listings_final.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, linewidths=.5, ax=ax)
corr['price'].sort_values(ascending=False)
# Out:
# price                          1.000000
# accommodates                   0.239997
# bedrooms                       0.225551
# bathrooms                      0.213528
# beds                           0.194283
# guests_included                0.101576
# amenities_length               0.032944
# review_scores_location         0.026195
# compound                       0.009562
# review_scores_cleanliness      0.006421
# host_response_rate            -0.010211
# review_scores_rating          -0.015529
# review_scores_accuracy        -0.019835
# review_scores_communication   -0.026142
# review_scores_value           -0.026846
# host_is_superhost             -0.029138
# review_scores_checkin         -0.042687
# Name: price, dtype: float64

# %%
#Creating columns for the categorical fields
listings_final = pd.get_dummies(listings_final, columns=['zipcode','property_type', 'room_type', 'bed_type'])

# %%
listings_final.dtypes
# Out:
# host_response_rate        float64
# host_is_superhost         float64
# accommodates                int64
# bathrooms                 float64
# bedrooms                  float64
#                            ...
# room_type_Hotel room        uint8
# room_type_Private room      uint8
# room_type_Shared room       uint8
# bed_type_Other              uint8
# bed_type_Real Bed           uint8
# Length: 2496, dtype: object

# %%
#Correlation Matrix
fig, ax = plt.subplots(figsize=(16,12))
corr = listings_final.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, linewidths=.5, ax=ax)
corr['price'].sort_values(ascending=False)
# Out:
# price                     1.000000
# zipcode_D08 K0HD          0.495557
# accommodates              0.239997
# bedrooms                  0.225551
# bathrooms                 0.213528
#                             ...
# review_scores_value      -0.026846
# room_type_Shared room    -0.027820
# host_is_superhost        -0.029138
# review_scores_checkin    -0.042687
# room_type_Private room   -0.135506
# Name: price, Length: 2496, dtype: float64

# %%
#Dropping rows with NAs
listings1=listings_final.dropna(subset = ['host_response_rate','review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value'])
listings1.isna().sum()
# Out:
# host_response_rate        0
# host_is_superhost         0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
#                          ..
# room_type_Hotel room      0
# room_type_Private room    0
# room_type_Shared room     0
# bed_type_Other            0
# bed_type_Real Bed         0
# Length: 2496, dtype: int64

# %%
#Creating Training / Test splits

target_name = 'price'
X = listings1.drop('price', axis=1)
y=listings1[target_name]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15, random_state=243)

# %%
#OLS Regression
Xp = X_train #Dependent variable
yp = y_train #Target outcome is price
Xp = sm.add_constant(Xp) 
ols_model = sm.OLS(yp, Xp.astype(float)).fit()

ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     1.215
# Date:                Sat, 21 Dec 2019   Prob (F-statistic):           5.73e-08
# Time:                        08:47:18   Log-Likelihood:                -47324.
# No. Observations:                6652   AIC:                         9.893e+04
# Df Residuals:                    4513   BIC:                         1.135e+05
# Df Model:                        2138
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -9.9589     57.401     -0.173      0.862    -122.493     102.576
# host_response_rate            -16.0317     13.772     -1.164      0.244     -43.031      10.967
# host_is_superhost              -5.8440     16.029     -0.365      0.715     -37.268      25.580
# accommodates                   39.3002      6.857      5.731      0.000      25.857      52.743
# bathrooms                      71.4794     12.535      5.702      0.000      46.905      96.054
# bedrooms                       34.7639     13.362      2.602      0.009       8.569      60.959
# beds                          -23.2913      8.472     -2.749      0.006     -39.900      -6.682
# guests_included               -16.2277      5.621     -2.887      0.004     -27.248      -5.208
# review_scores_rating            0.2420      1.301      0.186      0.852      -2.309       2.793
# review_scores_accuracy          0.2282     11.055      0.021      0.984     -21.444      21.901
# review_scores_cleanliness      13.4526      8.039      1.673      0.094      -2.309      29.214
# review_scores_checkin         -26.7383     10.950     -2.442      0.015     -48.206      -5.271
# review_scores_communication     2.0833     11.621      0.179      0.858     -20.699      24.866
# review_scores_location         14.3229      8.950      1.600      0.110      -3.223      31.869
# review_scores_value            -5.8968      9.505     -0.620      0.535     -24.532      12.738
# amenities_length               -0.0345      0.036     -0.965      0.335      -0.105       0.036
# compound                       -4.2059     13.144     -0.320      0.749     -29.974      21.562
# zipcode_-                      -4.6403    361.794     -0.013      0.990    -713.934     704.654
# zipcode_.                      25.9141    362.633      0.071      0.943    -685.024     736.852
# zipcode_......               -118.2439    363.346     -0.325      0.745    -830.580     594.093
# zipcode_/                     -24.8373    361.608     -0.069      0.945    -733.765     684.091
# zipcode_0                      16.7331     93.730      0.179      0.858    -167.023     200.489
# zipcode_00-000                 21.2088    361.897      0.059      0.953    -688.287     730.704
# zipcode_1                      -2.6498     63.472     -0.042      0.967    -127.085     121.786
# zipcode_10                    -63.1114    361.718     -0.174      0.861    -772.257     646.034
# zipcode_10710                 -82.5057    361.674     -0.228      0.820    -791.564     626.553
# zipcode_11                    -91.8923    181.084     -0.507      0.612    -446.906     263.122
# zipcode_12                    -84.4848    129.217     -0.654      0.513    -337.813     168.843
# zipcode_12RW30                -45.6769    361.727     -0.126      0.900    -754.839     663.485
# zipcode_13                    -80.3602    137.223     -0.586      0.558    -349.384     188.664
# zipcode_14                    -26.5461    121.109     -0.219      0.827    -263.980     210.887
# zipcode_15                    -15.3762     97.889     -0.157      0.875    -207.286     176.534
# zipcode_CW23                 -116.5971    362.331     -0.322      0.748    -826.943     593.749
# zipcode_Co                    -46.7548    362.288     -0.129      0.897    -757.016     663.506
# zipcode_Co Dublin             -76.3427    162.163     -0.471      0.638    -394.261     241.576
# zipcode_Co Wicklow            -52.8599    361.751     -0.146      0.884    -762.069     656.349
# zipcode_Co.                   -21.7628    361.762     -0.060      0.952    -730.994     687.469
# zipcode_Co. Dublin           -149.9326    368.735     -0.407      0.684    -872.835     572.969
# zipcode_Co.Dublin             -78.7224    183.958     -0.428      0.669    -439.370     281.925
# zipcode_Codublin               61.2981    362.110      0.169      0.866    -648.615     771.211
# zipcode_County Dublin         -97.8417    362.244     -0.270      0.787    -808.018     612.335
# zipcode_D 08                  -50.3972    361.499     -0.139      0.889    -759.113     658.319
# zipcode_D 1                   -76.7907    362.230     -0.212      0.832    -786.939     633.357
# zipcode_D 15                    3.2580    361.634      0.009      0.993    -705.723     712.239
# zipcode_D 8                    15.7543    255.872      0.062      0.951    -485.880     517.389
# zipcode_D.7                   -28.5301    361.910     -0.079      0.937    -738.050     680.990
# zipcode_D.8                   -21.7445    361.663     -0.060      0.952    -730.781     687.292
# zipcode_D.9.                 1.811e-10   1.37e-09      0.132      0.895   -2.51e-09    2.87e-09
# zipcode_D01                   -51.4725    162.120     -0.317      0.751    -369.307     266.362
# zipcode_D01 - FP48            -79.9026    361.672     -0.221      0.825    -788.956     629.151
# zipcode_D01 0000             -118.7300    163.156     -0.728      0.467    -438.595     201.135
# zipcode_D01 A489             2.242e-10    1.7e-09      0.132      0.895    -3.1e-09    3.55e-09
# zipcode_D01 A593               65.5978    361.645      0.181      0.856    -643.404     774.599
# zipcode_D01 AE86              -12.1938    361.774     -0.034      0.973    -721.449     697.061
# zipcode_D01 AE95               59.4739    362.349      0.164      0.870    -650.907     769.855
# zipcode_D01 AK50             -126.4632    362.047     -0.349      0.727    -836.252     583.326
# zipcode_D01 C925              -19.7235    361.827     -0.055      0.957    -729.082     689.635
# zipcode_D01 CD72               12.6943    361.750      0.035      0.972    -696.513     721.901
# zipcode_D01 CF21              -31.9681    362.006     -0.088      0.930    -741.677     677.741
# zipcode_D01 CH24              -62.8085    362.286     -0.173      0.862    -773.067     647.450
# zipcode_D01 CH63               45.6594    256.621      0.178      0.859    -457.444     548.762
# zipcode_D01 CT80             -158.2637    362.207     -0.437      0.662    -868.366     551.839
# zipcode_D01 DA58              -45.9806    361.873     -0.127      0.899    -755.429     663.468
# zipcode_D01 DK51            -8.661e-11    7.3e-10     -0.119      0.906   -1.52e-09    1.34e-09
# zipcode_D01 DY09              -18.0751    257.717     -0.070      0.944    -523.327     487.177
# zipcode_D01 E167               41.6914    362.089      0.115      0.908    -668.181     751.564
# zipcode_D01 E193              -69.6079    255.756     -0.272      0.786    -571.015     431.799
# zipcode_D01 E4E3              -36.2886    121.847     -0.298      0.766    -275.168     202.590
# zipcode_D01 E4F8               96.5864    362.140      0.267      0.790    -613.386     806.559
# zipcode_D01 E6C1               -3.6213    362.503     -0.010      0.992    -714.305     707.063
# zipcode_D01 TX45               60.1859    363.823      0.165      0.869    -653.086     773.458
# zipcode_D01 V0H6               -8.9852    257.466     -0.035      0.972    -513.745     495.775
# zipcode_D01 V0R6             1.054e-11   4.99e-11      0.211      0.833   -8.74e-11    1.08e-10
# zipcode_D01 V4H1            -3.175e-12   8.73e-12     -0.364      0.716   -2.03e-11    1.39e-11
# zipcode_D01 V8P8              -58.6905    361.669     -0.162      0.871    -767.740     650.359
# zipcode_D01 V9P2               -9.2527    215.631     -0.043      0.966    -431.994     413.489
# zipcode_D01 VH24              -31.2100    361.826     -0.086      0.931    -740.567     678.147
# zipcode_D01 VH90               59.8177    361.784      0.165      0.869    -649.456     769.092
# zipcode_D01 VK00               -4.9946    209.206     -0.024      0.981    -415.141     405.151
# zipcode_D01 VK84              -23.1040    361.696     -0.064      0.949    -732.204     685.996
# zipcode_D01 VW35              -25.6226    209.028     -0.123      0.902    -435.420     384.175
# zipcode_D01 VY32               40.7395    256.364      0.159      0.874    -461.859     543.338
# zipcode_D01 W0X6                1.0090    361.663      0.003      0.998    -708.028     710.046
# zipcode_D01 W0X8              -22.6833    361.620     -0.063      0.950    -731.635     686.269
# zipcode_D01 W3C8            -6.615e-13   3.58e-12     -0.185      0.853   -7.68e-12    6.36e-12
# zipcode_D01 W588             1.413e-12   7.86e-12      0.180      0.857    -1.4e-11    1.68e-11
# zipcode_D01 W5P8              107.0607    226.404      0.473      0.636    -336.802     550.924
# zipcode_D01 W5R9              434.6166    361.690      1.202      0.230    -274.473    1143.706
# zipcode_D01 W720               53.9187    181.862      0.296      0.767    -302.620     410.457
# zipcode_D01 W8C1              -31.8811    256.150     -0.124      0.901    -534.062     470.299
# zipcode_D01 W8H0               -5.5811    362.396     -0.015      0.988    -716.054     704.892
# zipcode_D01 WA07              -27.2039    137.004     -0.199      0.843    -295.799     241.392
# zipcode_D01 WC52               -8.1000    361.734     -0.022      0.982    -717.276     701.076
# zipcode_D01 WK25             5.882e-12   2.74e-11      0.214      0.830   -4.79e-11    5.97e-11
# zipcode_D01 WV83               26.8994    361.631      0.074      0.941    -682.074     735.873
# zipcode_D01 X045              405.0079    361.934      1.119      0.263    -304.561    1114.577
# zipcode_D01 X0F3              -14.5070    255.854     -0.057      0.955    -516.107     487.093
# zipcode_D01 X4F8               28.5577    181.464      0.157      0.875    -327.201     384.316
# zipcode_D01 X4W5              -84.5760    361.658     -0.234      0.815    -793.603     624.451
# zipcode_D01 X580              137.8062    362.156      0.381      0.704    -572.197     847.810
# zipcode_D01 X642               81.3508    363.217      0.224      0.823    -630.732     793.433
# zipcode_D01 X6E8              -38.1695    361.804     -0.105      0.916    -747.483     671.144
# zipcode_D01 X6P2              -56.0833    361.687     -0.155      0.877    -765.166     653.000
# zipcode_D01 X6W8             1.923e-12   9.67e-12      0.199      0.842    -1.7e-11    2.09e-11
# zipcode_D01 X778             -161.8164    368.792     -0.439      0.661    -884.829     561.196
# zipcode_D01 X858              148.1347    370.917      0.399      0.690    -579.044     875.314
# zipcode_D01 XC89              422.2402    361.563      1.168      0.243    -286.600    1131.081
# zipcode_D01 XE62             1.187e-12   7.09e-12      0.167      0.867   -1.27e-11    1.51e-11
# zipcode_D01 XE95              403.7447    361.791      1.116      0.264    -305.544    1113.033
# zipcode_D01 XK19               11.2804    181.784      0.062      0.951    -345.105     367.666
# zipcode_D01 XN65              -52.7143    361.667     -0.146      0.884    -761.759     656.330
# zipcode_D01 XV52              -23.1814    361.930     -0.064      0.949    -732.741     686.378
# zipcode_D01 XW93               11.0826    361.965      0.031      0.976    -698.546     720.711
# zipcode_D01 XY44              -50.6342    138.677     -0.365      0.715    -322.508     221.240
# zipcode_D01 XY96               58.9409    362.789      0.162      0.871    -652.303     770.185
# zipcode_D01 Y048              -32.6221    361.490     -0.090      0.928    -741.320     676.076
# zipcode_D01 Y153               56.9880    362.846      0.157      0.875    -654.368     768.344
# zipcode_D01 Y1F7               -2.5437    362.162     -0.007      0.994    -712.558     707.470
# zipcode_D01 Y1T9               29.5011    361.764      0.082      0.935    -679.734     738.737
# zipcode_D01 Y273               -4.6810    361.781     -0.013      0.990    -713.949     704.587
# zipcode_D01 Y310               36.9490    361.690      0.102      0.919    -672.140     746.038
# zipcode_D01 Y364              -32.4696    361.577     -0.090      0.928    -741.337     676.398
# zipcode_D01 Y650              -91.3196    362.000     -0.252      0.801    -801.016     618.377
# zipcode_D01 Y6Y6              -12.0791    255.878     -0.047      0.962    -513.725     489.567
# zipcode_D01 Y865              -25.8317    362.274     -0.071      0.943    -736.066     684.402
# zipcode_D01 Y9T1              -20.8215    256.106     -0.081      0.935    -522.914     481.271
# zipcode_D01 YD76               54.7212    363.101      0.151      0.880    -657.134     766.577
# zipcode_D01 YH93              -25.9598    362.481     -0.072      0.943    -736.600     684.680
# zipcode_D01 YK11             -161.8425    361.784     -0.447      0.655    -871.117     547.432
# zipcode_D01 YK57             -109.6743    361.942     -0.303      0.762    -819.258     599.909
# zipcode_D01 YK65              -39.7050    363.560     -0.109      0.913    -752.460     673.050
# zipcode_D01 YP22              -15.9913    361.597     -0.044      0.965    -724.899     692.916
# zipcode_D01 YV66              -27.8683    361.710     -0.077      0.939    -736.998     681.261
# zipcode_D01 YX82              -28.7623    361.856     -0.079      0.937    -738.177     680.652
# zipcode_D01A251                -0.3543    361.558     -0.001      0.999    -709.185     708.476
# zipcode_D01C2F6                61.0401     92.943      0.657      0.511    -121.173     243.253
# zipcode_D01FP95               -27.5693    361.985     -0.076      0.939    -737.238     682.099
# zipcode_D01KA44               -16.6719    361.838     -0.046      0.963    -726.052     692.708
# zipcode_D01NV22             -7.887e-12    3.4e-11     -0.232      0.817   -7.46e-11    5.88e-11
# zipcode_D01P5R7               -16.3380    361.820     -0.045      0.964    -725.683     693.007
# zipcode_D02 0000              -26.3231    256.643     -0.103      0.918    -529.469     476.823
# zipcode_D02 A008              -32.0980    362.196     -0.089      0.929    -742.180     677.983
# zipcode_D02 A327               44.0346    362.101      0.122      0.903    -665.861     753.930
# zipcode_D02 A329               13.7717    361.678      0.038      0.970    -695.295     722.838
# zipcode_D02 A342             9.832e-13   5.08e-12      0.193      0.847   -8.98e-12    1.09e-11
# zipcode_D02 A394            -9.678e-12   4.66e-11     -0.208      0.835   -1.01e-10    8.16e-11
# zipcode_D02 A430              -41.4934    362.245     -0.115      0.909    -751.672     668.685
# zipcode_D02 AE77               19.8139    361.701      0.055      0.956    -689.296     728.924
# zipcode_D02 AK29              -10.7345    361.958     -0.030      0.976    -720.350     698.881
# zipcode_D02 AX96              -68.3398    361.908     -0.189      0.850    -777.857     641.177
# zipcode_D02 CC02               76.3473    256.279      0.298      0.766    -426.086     578.780
# zipcode_D02 CC89               15.8359    362.041      0.044      0.965    -693.941     725.613
# zipcode_D02 CC96             -3.51e-12   1.59e-11     -0.221      0.825   -3.47e-11    2.77e-11
# zipcode_D02 CF62               26.7923    362.719      0.074      0.941    -684.314     737.899
# zipcode_D02 CH21              260.6164    361.919      0.720      0.472    -448.922     970.154
# zipcode_D02 CH24              -33.0625    361.698     -0.091      0.927    -742.168     676.043
# zipcode_D02 CH68              -84.2609    361.858     -0.233      0.816    -793.679     625.158
# zipcode_D02 CH94              -50.5633    361.851     -0.140      0.889    -759.968     658.842
# zipcode_D02 CR40            -4.297e-12   1.77e-11     -0.243      0.808    -3.9e-11    3.04e-11
# zipcode_D02 DA02             5.895e-13   5.46e-12      0.108      0.914   -1.01e-11    1.13e-11
# zipcode_D02 DK06               19.9388    361.823      0.055      0.956    -689.412     729.289
# zipcode_D02 DK09              -70.4141    362.179     -0.194      0.846    -780.461     639.633
# zipcode_D02 DK38              108.7473    361.898      0.300      0.764    -600.751     818.246
# zipcode_D02 DV26              -89.4945    362.066     -0.247      0.805    -799.322     620.333
# zipcode_D02 DW32              -13.1946    361.603     -0.036      0.971    -722.114     695.724
# zipcode_D02 DY65               24.4946    361.814      0.068      0.946    -684.838     733.828
# zipcode_D02 E180             9.294e-12   3.97e-11      0.234      0.815   -6.85e-11     8.7e-11
# zipcode_D02 E761              -29.3088    361.822     -0.081      0.935    -738.657     680.040
# zipcode_D02 E972              272.1694    363.059      0.750      0.454    -439.604     983.943
# zipcode_D02 E981              -66.0986    256.087     -0.258      0.796    -568.155     435.958
# zipcode_D02 EC67              132.1755    363.243      0.364      0.716    -579.958     844.309
# zipcode_D02 EH05               32.5139    361.931      0.090      0.928    -677.048     742.076
# zipcode_D02 EH66              186.6983    363.006      0.514      0.607    -524.972     898.368
# zipcode_D02 EK20               -4.6362    362.131     -0.013      0.990    -714.590     705.318
# zipcode_D02 EW29              -84.0716    255.930     -0.328      0.743    -585.819     417.676
# zipcode_D02 F201               19.1365    372.212      0.051      0.959    -710.582     748.855
# zipcode_D02 F206              -50.0327    208.981     -0.239      0.811    -459.738     359.672
# zipcode_D02 F240               46.3263    361.744      0.128      0.898    -662.870     755.522
# zipcode_D02 F635             -146.1305    259.127     -0.564      0.573    -654.146     361.885
# zipcode_D02 F662               56.4371    362.402      0.156      0.876    -654.049     766.923
# zipcode_D02 F683            -3.492e-12   1.52e-11     -0.230      0.818   -3.33e-11    2.63e-11
# zipcode_D02 F704               70.3446    362.584      0.194      0.846    -640.497     781.186
# zipcode_D02 FH22              168.4129    363.147      0.464      0.643    -543.532     880.358
# zipcode_D02 FK28            -7.115e-12   3.16e-11     -0.225      0.822   -6.91e-11    5.49e-11
# zipcode_D02 FK71              -36.8011    361.629     -0.102      0.919    -745.770     672.168
# zipcode_D02 FT67            -2.606e-14    1.7e-12     -0.015      0.988   -3.37e-12    3.32e-12
# zipcode_D02 FX33             5.734e-12   2.66e-11      0.216      0.829   -4.64e-11    5.79e-11
# zipcode_D02 H920              -22.3943    363.784     -0.062      0.951    -735.590     690.801
# zipcode_D02 H922               50.3725    361.742      0.139      0.889    -658.819     759.564
# zipcode_D02 H924              129.3695    361.958      0.357      0.721    -580.246     838.985
# zipcode_D02 HD45               15.3213    362.261      0.042      0.966    -694.888     725.531
# zipcode_D02 HE17                9.3191    362.565      0.026      0.979    -701.486     720.125
# zipcode_D02 HF61               14.8404    361.619      0.041      0.967    -694.111     723.792
# zipcode_D02 HF72              -39.4066    361.674     -0.109      0.913    -748.465     669.652
# zipcode_D02 HX66              245.8835    368.781      0.667      0.505    -477.107     968.874
# zipcode_D02 K020               11.1369    362.038      0.031      0.975    -698.635     720.909
# zipcode_D02 K028            -2.746e-12   1.11e-11     -0.247      0.805   -2.46e-11    1.91e-11
# zipcode_D02 K029             7.016e-12   3.26e-11      0.215      0.830   -5.69e-11    7.09e-11
# zipcode_D02 K129             -160.2816    368.037     -0.436      0.663    -881.815     561.252
# zipcode_D02 K135             -139.9397    361.942     -0.387      0.699    -849.523     569.644
# zipcode_D02 K286               -2.0769    209.517     -0.010      0.992    -412.833     408.680
# zipcode_D02 K302               97.7404    362.126      0.270      0.787    -612.204     807.685
# zipcode_D02 K376              318.0762    362.018      0.879      0.380    -391.656    1027.808
# zipcode_D02 KC89              157.0690    362.373      0.433      0.665    -553.360     867.498
# zipcode_D02 KD35               15.6419    162.228      0.096      0.923    -302.405     333.688
# zipcode_D02 KF21            -8.357e-12   3.96e-11     -0.211      0.833    -8.6e-11    6.93e-11
# zipcode_D02 KH52               -0.0315    209.101     -0.000      1.000    -409.972     409.909
# zipcode_D02 KN67              -29.8598    361.730     -0.083      0.934    -739.029     679.309
# zipcode_D02 KP29                3.7781    361.730      0.010      0.992    -705.390     712.946
# zipcode_D02 KW02               92.8084    361.723      0.257      0.798    -616.346     801.962
# zipcode_D02 KW21                6.3106    361.641      0.017      0.986    -702.684     715.305
# zipcode_D02 N228              -70.7560    361.612     -0.196      0.845    -779.693     638.181
# zipcode_D02 N296              -29.8272    361.827     -0.082      0.934    -739.186     679.532
# zipcode_D02 N440              -14.9359    361.615     -0.041      0.967    -723.879     694.007
# zipcode_D02 N725               28.6466    209.814      0.137      0.891    -382.692     439.985
# zipcode_D02 NH96               15.6627    256.906      0.061      0.951    -487.999     519.324
# zipcode_D02 NP23               77.2415    361.844      0.213      0.831    -632.150     786.633
# zipcode_D02 NW01              -20.5147    362.391     -0.057      0.955    -730.978     689.949
# zipcode_D02 NX25              991.3261    182.155      5.442      0.000     634.212    1348.440
# zipcode_D02 NX30              -18.2270    361.529     -0.050      0.960    -727.002     690.548
# zipcode_D02 P215              -33.1879    361.783     -0.092      0.927    -742.459     676.083
# zipcode_D02 P782            -3.281e-12   1.28e-11     -0.257      0.797   -2.83e-11    2.18e-11
# zipcode_D02 P891              -49.5798    361.794     -0.137      0.891    -758.873     659.713
# zipcode_D02 P954                6.0928    361.612      0.017      0.987    -702.844     715.030
# zipcode_D02 PE00              174.8552    363.321      0.481      0.630    -537.432     887.142
# zipcode_D02 PH32                8.3057    361.558      0.023      0.982    -700.525     717.136
# zipcode_D02 PN30              -67.1299    361.634     -0.186      0.853    -776.109     641.850
# zipcode_D02 PP78               -2.6742    361.616     -0.007      0.994    -711.619     706.271
# zipcode_D02 PR66              -26.2705    361.709     -0.073      0.942    -735.396     682.855
# zipcode_D02 PT18             2.504e-11   1.13e-10      0.222      0.825   -1.96e-10    2.46e-10
# zipcode_D02 PX75              158.5927    212.731      0.746      0.456    -258.464     575.649
# zipcode_D02 PY10               -4.5092    256.480     -0.018      0.986    -507.336     498.317
# zipcode_D02 PY16               80.0554    365.447      0.219      0.827    -636.399     796.510
# zipcode_D02 PY80                9.7881    256.064      0.038      0.970    -492.222     511.799
# zipcode_D02 RC97               38.8771    362.591      0.107      0.915    -671.978     749.733
# zipcode_D02 RK37               26.9376    362.145      0.074      0.941    -683.044     736.919
# zipcode_D02 RP76               10.0752    361.641      0.028      0.978    -698.918     719.068
# zipcode_D02 RR98               63.8205    209.423      0.305      0.761    -346.751     474.392
# zipcode_D02 RY67              144.5627    362.007      0.399      0.690    -565.149     854.274
# zipcode_D02 TC21              -77.2861    362.026     -0.213      0.831    -787.034     632.462
# zipcode_D02 TH63               19.4400    362.244      0.054      0.957    -690.736     729.616
# zipcode_D02 TK52              107.0934    361.734      0.296      0.767    -602.082     816.268
# zipcode_D02 TX05               24.0328    361.994      0.066      0.947    -685.652     733.717
# zipcode_D02 TY72            -1.012e-11   4.26e-11     -0.238      0.812   -9.36e-11    7.34e-11
# zipcode_D02 V256               12.8020    361.562      0.035      0.972    -696.037     721.641
# zipcode_D02 V820              -66.8974    361.810     -0.185      0.853    -776.223     642.428
# zipcode_D02 VK49              -16.8214    361.974     -0.046      0.963    -726.468     692.826
# zipcode_D02 VK64             -234.2653    362.510     -0.646      0.518    -944.963     476.433
# zipcode_D02 VY17              -31.6110    361.585     -0.087      0.930    -740.496     677.274
# zipcode_D02 VY22               33.4929    361.869      0.093      0.926    -675.947     742.933
# zipcode_D02 W181               31.2352    362.207      0.086      0.931    -678.867     741.337
# zipcode_D02 W258              -35.3334    209.205     -0.169      0.866    -445.478     374.811
# zipcode_D02 W300.              71.5356    362.563      0.197      0.844    -639.265     782.336
# zipcode_D02 W597            -1.253e-11   5.92e-11     -0.212      0.832   -1.29e-10    1.04e-10
# zipcode_D02 W683              -43.4762    361.946     -0.120      0.904    -753.068     666.116
# zipcode_D02 W685                2.9591    361.632      0.008      0.993    -706.017     711.936
# zipcode_D02 WD30               99.1567    257.768      0.385      0.700    -406.195     604.509
# zipcode_D02 WF84               60.9801    362.056      0.168      0.866    -648.826     770.787
# zipcode_D02 WK59              -63.7335    256.389     -0.249      0.804    -566.381     438.914
# zipcode_D02 WK72             4.102e-12   1.92e-11      0.213      0.831   -3.36e-11    4.18e-11
# ...
# zipcode_K32P761               -10.6760    362.236     -0.029      0.976    -720.836     699.484
# zipcode_K34 A062               29.8914    361.863      0.083      0.934    -679.537     739.320
# zipcode_K34 C592              -80.1623    361.816     -0.222      0.825    -789.500     629.175
# zipcode_K34 C667              -23.4161    256.313     -0.091      0.927    -525.915     479.083
# zipcode_K34 EN24             -208.2473    362.536     -0.574      0.566    -918.996     502.501
# zipcode_K34 F218              -71.6731    361.760     -0.198      0.843    -780.900     637.554
# zipcode_K34 NH42             -3.85e-11   9.81e-10     -0.039      0.969   -1.96e-09    1.88e-09
# zipcode_K34 NP59            -2.184e-10   6.17e-10     -0.354      0.723   -1.43e-09    9.92e-10
# zipcode_K34 R688              -75.4530    363.343     -0.208      0.836    -787.783     636.877
# zipcode_K34 T856              -70.6477    361.629     -0.195      0.845    -779.618     638.323
# zipcode_K34 V076              108.1310    362.123      0.299      0.765    -601.807     818.069
# zipcode_K34 VE22               25.7845    362.176      0.071      0.943    -684.258     735.827
# zipcode_K34 W292             -228.0385    362.047     -0.630      0.529    -937.828     481.751
# zipcode_K34 W525             -149.0884    362.328     -0.411      0.681    -859.429     561.252
# zipcode_K34 W563              -11.0469    361.676     -0.031      0.976    -720.108     698.015
# zipcode_K34 WF60            -2.457e-10   9.97e-10     -0.246      0.805    -2.2e-09    1.71e-09
# zipcode_K34 WR28              -41.9500    361.966     -0.116      0.908    -751.580     667.680
# zipcode_K34 X363               83.8227    361.922      0.232      0.817    -625.722     793.367
# zipcode_K34 X859               32.1427    361.899      0.089      0.929    -677.356     741.641
# zipcode_K34 XA46             2.833e-10   9.98e-10      0.284      0.777   -1.67e-09    2.24e-09
# zipcode_K34 XA62             -274.4312    362.362     -0.757      0.449    -984.839     435.977
# zipcode_K34 XK02              -30.2023    361.951     -0.083      0.934    -739.804     679.399
# zipcode_K34 Y651             -260.4813    362.249     -0.719      0.472    -970.666     449.704
# zipcode_K34 YV84              -26.9165    361.958     -0.074      0.941    -736.532     682.699
# zipcode_K34XA46             -5.273e-10   9.99e-10     -0.528      0.598   -2.49e-09    1.43e-09
# zipcode_K36 AE95               97.5198    361.938      0.269      0.788    -612.057     807.097
# zipcode_K36 AK60             -201.0465    362.457     -0.555      0.579    -911.639     509.547
# zipcode_K36 D434             -125.4684    361.647     -0.347      0.729    -834.474     583.537
# zipcode_K36 D635             -247.9701    362.731     -0.684      0.494    -959.100     463.160
# zipcode_K36 DC64               44.9299    362.027      0.124      0.901    -664.819     754.679
# zipcode_K36 DP66               18.7834    361.879      0.052      0.959    -690.677     728.244
# zipcode_K36 E004               -5.8350    362.150     -0.016      0.987    -715.825     704.155
# zipcode_K36 E285              -22.9974    361.866     -0.064      0.949    -732.432     686.437
# zipcode_K36 EC99               12.1858    256.154      0.048      0.962    -490.001     514.373
# zipcode_K36 ED21               46.0579    362.552      0.127      0.899    -664.721     756.836
# zipcode_K36 F991                1.7107    361.634      0.005      0.996    -707.269     710.690
# zipcode_K67 E278               -7.3353    209.171     -0.035      0.972    -417.412     402.742
# zipcode_K67 E892              -44.3766    361.727     -0.123      0.902    -753.539     664.786
# zipcode_K67 EW72            -4.452e-10   9.94e-10     -0.448      0.654   -2.39e-09     1.5e-09
# zipcode_K67 H6X3              -51.0112    361.845     -0.141      0.888    -760.404     658.381
# zipcode_K67 H9F8               60.7843    361.924      0.168      0.867    -648.764     770.333
# zipcode_K67 HH59             -105.5153    361.652     -0.292      0.770    -814.531     603.500
# zipcode_K67 K231              -19.4664    361.711     -0.054      0.957    -728.598     689.665
# zipcode_K67 K710             3.743e-10   9.87e-10      0.379      0.704   -1.56e-09    2.31e-09
# zipcode_K67 KT63             9.645e-14   3.01e-13      0.320      0.749   -4.94e-13    6.87e-13
# zipcode_K67 KX58               -9.2083    361.783     -0.025      0.980    -718.480     700.063
# zipcode_K67 N9K8               -8.9349    361.636     -0.025      0.980    -717.918     700.048
# zipcode_K67 NX94               31.3478    361.835      0.087      0.931    -678.026     740.721
# zipcode_K67 P084              -73.7942    361.736     -0.204      0.838    -782.973     635.385
# zipcode_K67 PP44              -17.1224    361.679     -0.047      0.962    -726.190     691.945
# zipcode_K67 PT85              -19.4725    361.655     -0.054      0.957    -728.493     689.548
# zipcode_K67 RF96               15.0723    361.694      0.042      0.967    -694.024     724.169
# zipcode_K67 T634               -9.1180    362.137     -0.025      0.980    -719.084     700.848
# zipcode_K67 T8P9              -44.3550    361.859     -0.123      0.902    -753.776     665.066
# zipcode_K67 TC65              -13.2155    361.736     -0.037      0.971    -722.396     695.965
# zipcode_K67 V3F2               61.2016    361.946      0.169      0.866    -648.389     770.792
# zipcode_K67 VF21               32.4821    211.879      0.153      0.878    -382.905     447.869
# zipcode_K67 X659               -6.3465    361.700     -0.018      0.986    -715.456     702.763
# zipcode_K67 XC67             -202.8541    362.536     -0.560      0.576    -913.601     507.893
# zipcode_K67 XP90               22.8901    361.649      0.063      0.950    -686.119     731.900
# zipcode_K67 XR71              -71.2498    361.892     -0.197      0.844    -780.735     638.235
# zipcode_K67 YV12              -14.7480    361.718     -0.041      0.967    -723.891     694.396
# zipcode_K67 YY36             9.391e-11   9.98e-10      0.094      0.925   -1.86e-09    2.05e-09
# zipcode_K67EA03                30.0435    362.059      0.083      0.934    -679.769     739.856
# zipcode_K67FH58                18.3306    362.175      0.051      0.960    -691.710     728.371
# zipcode_K67HP70               -19.4696    361.898     -0.054      0.957    -728.966     690.027
# zipcode_K6PD25               6.397e-10   9.98e-10      0.641      0.522   -1.32e-09     2.6e-09
# zipcode_K78 C524              -37.3517    361.792     -0.103      0.918    -746.642     671.938
# zipcode_K78 C9T1             -124.4146    362.380     -0.343      0.731    -834.856     586.027
# zipcode_K78 DK15              -62.6498    361.729     -0.173      0.863    -771.816     646.516
# zipcode_K78 E082                5.3622    362.001      0.015      0.988    -704.336     715.061
# zipcode_K78 F584              -17.0259    361.697     -0.047      0.962    -726.130     692.078
# zipcode_K78 FP71             -231.9778    258.655     -0.897      0.370    -739.068     275.113
# zipcode_K78 FW18              -58.6227    361.866     -0.162      0.871    -768.057     650.811
# zipcode_K78 H2D8               13.1184    361.932      0.036      0.971    -696.445     722.682
# zipcode_K78 KN76               -8.0641    361.610     -0.022      0.982    -716.997     700.869
# zipcode_K78 N288             -116.7695    362.121     -0.322      0.747    -826.705     593.166
# zipcode_K78 N638              -47.9095    362.236     -0.132      0.895    -758.070     662.251
# zipcode_K78 N998              -16.6860    361.901     -0.046      0.963    -726.190     692.818
# zipcode_K78 P7X3               77.6916    256.901      0.302      0.762    -425.960     581.344
# zipcode_K78 WV00              -15.4326    361.606     -0.043      0.966    -724.357     693.492
# zipcode_K78 X098               -6.0005    209.520     -0.029      0.977    -416.761     404.760
# zipcode_K78 X571             -138.3814    361.792     -0.382      0.702    -847.671     570.908
# zipcode_K78 X895             -124.1176    362.094     -0.343      0.732    -833.999     585.764
# zipcode_K78 XC58             -155.2093    361.767     -0.429      0.668    -864.449     554.030
# zipcode_K78 Y2X9               47.0880    362.337      0.130      0.897    -663.269     757.445
# zipcode_K78 Y9Y0             -293.8219    362.490     -0.811      0.418   -1004.479     416.835
# zipcode_N/a                   -72.3089    362.142     -0.200      0.842    -782.284     637.666
# zipcode_Na                     28.4776    181.058      0.157      0.875    -326.485     383.440
# zipcode_None                  -33.7573    361.918     -0.093      0.926    -743.293     675.779
# zipcode_Phibsborough          -92.8421    362.455     -0.256      0.798    -803.431     617.747
# zipcode_Ringsend, Dublin 4    -16.0231    361.746     -0.044      0.965    -725.223     693.176
# zipcode_South                -119.9290    362.148     -0.331      0.741    -829.917     590.059
# zipcode_X                    4.276e-10   9.99e-10      0.428      0.669   -1.53e-09    2.39e-09
# zipcode_Xx                     25.5248    361.706      0.071      0.944    -683.597     734.646
# zipcode_co                    -82.4314    363.434     -0.227      0.821    -794.941     630.078
# zipcode_d01a977               -14.6750    361.583     -0.041      0.968    -723.555     694.205
# zipcode_d12rv08                11.2003    362.362      0.031      0.975    -699.206     721.607
# zipcode_d15                    43.8350    362.093      0.121      0.904    -666.045     753.715
# zipcode_d18                  -165.7295    182.485     -0.908      0.364    -523.490     192.031
# zipcode_d2                    -45.2552    362.349     -0.125      0.901    -755.638     665.127
# zipcode_d4                     93.2289    361.618      0.258      0.797    -615.719     802.177
# zipcode_d5                    -47.7994    369.582     -0.129      0.897    -772.361     676.762
# zipcode_d8                     35.7090    362.604      0.098      0.922    -675.171     746.589
# zipcode_dublin 4              -29.5504    362.197     -0.082      0.935    -739.634     680.533
# zipcode_dublin 7              -35.9920    361.502     -0.100      0.921    -744.713     672.729
# zipcode_dublin 8              -25.3952    255.895     -0.099      0.921    -527.075     476.285
# zipcode_dublin 9             -237.7678    363.316     -0.654      0.513    -950.045     474.510
# zipcode_dublin6w              -30.0629    362.370     -0.083      0.934    -740.485     680.359
# zipcode_dublin7                -4.0765    361.743     -0.011      0.991    -713.269     705.116
# zipcode_na                     -3.7215    361.566     -0.010      0.992    -712.568     705.125
# property_type_Apartment        19.9375     16.897      1.180      0.238     -13.189      53.064
# property_type_Condominium     -14.4701     25.659     -0.564      0.573     -64.775      35.834
# property_type_House           -28.8917     18.807     -1.536      0.125     -65.762       7.979
# property_type_Other            13.4655     19.736      0.682      0.495     -25.227      52.159
# room_type_Entire home/apt     -41.7534     26.026     -1.604      0.109     -92.776       9.269
# room_type_Hotel room           88.6164     57.059      1.553      0.120     -23.246     200.479
# room_type_Private room        -17.3060     24.937     -0.694      0.488     -66.194      31.582
# room_type_Shared room         -39.5158     45.458     -0.869      0.385    -128.635      49.603
# bed_type_Other                 -4.8985     54.845     -0.089      0.929    -112.422     102.625
# bed_type_Real Bed              -5.0603     40.644     -0.125      0.901     -84.743      74.622
# ==============================================================================
# Omnibus:                    22440.272   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4921378886.152
# Skew:                          60.374   Prob(JB):                         0.00
# Kurtosis:                    4215.060   Cond. No.                     2.96e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Using OLS regression from sklearn
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Checking for features with most importance
ols_coefficients = pd.DataFrame({'feature': X_train.columns, 'importance': lm.coef_})
ols_coefficients.sort_values('importance', ascending=False)[:10].plot(x='feature', y='importance', kind='bar')

# %%
#OLS mean squared error on test dataset 
ols_y_predict = lm.predict(X_test)
ols_mse = np.sqrt(metrics.mean_squared_error(y_test, ols_y_predict))
ols_mse
# Out:
# 10524319535.667906

# %%
ols_r2 = metrics.r2_score(y_test, ols_y_predict)
ols_r2
# Out:
# -7863175344865121.0

# %%
#Creating decision tree model
dtree = tree.DecisionTreeClassifier(
    class_weight="balanced",
    min_weight_fraction_leaf=0.01,)
dtree = dtree.fit(X_train,y_train)

#Checking for important features
importances = dtree.feature_importances_
feat_names = X_train.columns
tree_result = pd.DataFrame({'feature': feat_names, 'importance': importances})
tree_result.sort_values(by='importance',ascending=False)[:10].plot(x='feature', y='importance', kind='bar')

# %%
#Decision Tree mean squared error on test dataset
dtree_y_predict = dtree.predict(X_test)
dtree_mse = np.sqrt(metrics.mean_squared_error(y_test, dtree_y_predict))
dtree_mse
# Out:
# 1965.4610401916068

# %%
dtree_r2 = metrics.r2_score(y_test, dtree_y_predict)
dtree_r2
# Out:
# -273.24504426980906

# %%
#Creating random forest model
rf = RandomForestRegressor(max_depth=3, random_state=0)
rf.fit(X_train, y_train)
rf_importances = rf.feature_importances_
rf_result = pd.DataFrame({'feature': feat_names, 'importance': rf_importances})
rf_result.sort_values(by='importance',ascending=False)[:10].plot(x='feature', y='importance', kind='bar')

# %%
#Get Random Forest mean squared error on test dataset
rf_y_predict = rf.predict(X_test)
rf_mse = np.sqrt(metrics.mean_squared_error(y_test, rf_y_predict))
rf_mse
# Out:
# 102.51082211492623

# %%
rf_r2 = metrics.r2_score(y_test, rf_y_predict)
rf_r2
# Out:
# 0.2539819382185503

# %%
print("OLS MSE",ols_mse)
print("Decision Tree MSE:", dtree_mse)
print("Random Forest MSE:", rf_mse)
# Out:
# OLS MSE 10524319535.667906
# Decision Tree MSE: 1965.4610401916068
# Random Forest MSE: 102.51082211492623

# %%
print("OLS R^2",ols_r2)
print("Decision Tree R^2:", dtree_r2)
print("Random Forest R^2:", rf_r2)
# Out:
# OLS R^2 -7863175344865121.0
# Decision Tree R^2: -273.24504426980906
# Random Forest R^2: 0.2539819382185503
